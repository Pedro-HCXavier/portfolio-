# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('empresasEUA.csv')
df_cortado = df.head(10)
df_cortado
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# ...

# %%
df_cortado.info()
# A coluna Revenue (usd millions) tem conteúdo em string
# É necessário transformar em número
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    10 non-null     int64
#  1   Name                    10 non-null     object
#  2   Industry                10 non-null     object
#  3   Revenue (USD millions)  10 non-null     object
#  4   Revenue growth          10 non-null     object
#  5   Employees               10 non-null     object
#  6   Headquarters            10 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes

# %%
import numpy as np
# Criando o espaço em que o gráfico vai aparecer
figura, eixo = plt.subplots(figsize=(16,9))

nome = df_cortado.Name
# transformando essa coluna em valor numérico
receita = df_cortado['Revenue (USD millions)'].str.replace(',', '').astype(int)


eixo.barh(nome, receita, color = 'lightgreen')

# Colocando os números ao lado de cada barra
for i in eixo.patches:
    plt.text(i.get_width()+0.3, i.get_y()+0.5, 
             str(f'{int(i.get_width() / 1000)}M'),
             fontsize = 10, fontweight ='bold',
             color ='white')

# Estilizando o gráfico
eixo.set_title('Empresas mais ricas dos EUA')

eixo.set_facecolor('slategray')
figura.set_facecolor('slategray')

#for s in ['top', 'bottom', 'left', 'right']:
 #   eixo.spines[s].set_visible(False)

eixo.invert_yaxis()

eixo.xaxis.set_ticks_position('none')
eixo.yaxis.set_ticks_position('none')

eixo.grid(color ='silver',
        linestyle ='-.', linewidth = 0.9,
        alpha = 0.3)

plt.xticks((100000,200000,300000,400000,500000,600000),('100M','200M','300M','400M','500M','600M'))

eixo.set_xlabel('Receita (US$)')
plt.show()
